# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %%
# Return the first row formatted as a table.
print(recent_grads.iloc[0])

# %%
# Explore data structure and dataframe
print(recent_grads.head())
print(recent_grads.tail())
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
# Remove and drop all rows with missing or NA values to clean dataset
recent_grads = recent_grads.dropna()

# %%
# Generate scatterplot for each of the following relationships:
# Sample_size and Median
# Full_time and Median
# ShareWomen and Unemployment_rate
# Men and Median
# Women and Median

# %%
import seaborn as sns

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', c="green")

# %%
sns.regplot(x=recent_grads["Sample_size"], y=recent_grads["Median"])

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', c="green")

# %%
sns.regplot(x=recent_grads["Full_time"], y=recent_grads["Median"])

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', c="green")

# %%
sns.regplot(x=recent_grads["ShareWomen"], y=recent_grads["Unemployment_rate"])

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', c="green")

# %%
sns.regplot(x=recent_grads["Men"], y=recent_grads["Median"])

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', c="green")

# %%
sns.regplot(x=recent_grads["Women"], y=recent_grads["Median"])

# %%
# Do students in more popular majors make more money?

# %%
# Do students that majored in subjects that were majority female make more money?

# %%
# Is there any link between the number of full-time employees and median salary?

# %%
# Generate histograms in separate jupyter notebook cells to explore the distributions of the following columns using different bin sizes and ranges:
# Sample_size, Median, Employed, Full_time, ShareWomen, Unemployment_rate, Men, Women

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for item in range(1,5):
    ax = fig.add_subplot(4,1,item)
    ax = recent_grads[cols[item]].plot(kind='hist', rot=20)

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for r in range(4,8):
    ax = fig.add_subplot(4,1,r-3)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=20)

# %%
recent_grads['Sample_size'].hist(color="orange",bins=200, range=(0,5000))
plt.xlabel("Sample Size", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Sample_size'],kde = True,color="r",vertical=True,rug=False,bins=200)
plt.title('Distribution', fontsize=15)
plt.xlabel('Sample Size', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['Median'].hist(color="orange",bins=50, range=(0,130000))
plt.xlabel("Median", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Median'],kde = True,color="r",vertical=True,rug=False,bins=50)
plt.title('Distribution', fontsize=15)
plt.xlabel('Median', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['Employed'].hist(color="orange",bins=300, range=(0,400000))
plt.xlabel("Employed", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Employed'],kde = True,color="r",vertical=True,rug=False,bins=300)
plt.title('Distribution', fontsize=15)
plt.xlabel('Employed', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['Full_time'].hist(color="orange",bins=200, range=(0,300000))
plt.xlabel("Full Time", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Full_time'],kde = True,color="r",vertical=True,rug=False,bins=200)
plt.title('Distribution', fontsize=15)
plt.xlabel('Full Time', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['ShareWomen'].hist(color="orange",bins=100, range=(0,2))
plt.xlabel("Share Women", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['ShareWomen'],kde = True,color="r",vertical=True,rug=False,bins=100)
plt.title('Distribution', fontsize=15)
plt.xlabel('Share Women', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['Unemployment_rate'].hist(color="orange",bins=100, range=(0,1))
plt.xlabel("Unemployment Rate", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Unemployment_rate'],kde = True,color="r",vertical=True,rug=False,bins=100)
plt.title('Distribution', fontsize=15)
plt.xlabel('Unemployment Rate', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['Men'].hist(color="orange",bins=100, range=(0,200000))
plt.xlabel("Men", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Men'],kde = True,color="r",vertical=True,rug=False,bins=100)
plt.title('Distribution', fontsize=15)
plt.xlabel('Men', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
recent_grads['Women'].hist(color="orange",bins=200, range=(0,350000))
plt.xlabel("Women", fontsize=13)
plt.ylabel("Frequency",fontsize=13)
plt.xscale('log')

# %%
sns.distplot(recent_grads['Women'],kde = True,color="r",vertical=True,rug=False,bins=200)
plt.title('Distribution', fontsize=15)
plt.xlabel('Women', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f759001fe10>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f758fe860f0>,
# ...
#       dtype=object)

# %%
sns.set_palette("RdBu", 4)
sns.pairplot(recent_grads, vars=["Sample_size", "Median"])

# %%
sns.set_palette("RdBu", 4)
sns.pairplot(recent_grads, vars=["Sample_size", "Median","Unemployment_rate"])

# %%
# What percent of majors are predominantly male? Predominantly female?
# What's the most common median salary range?

# %%
recent_grads.shape
# Out:
# (172, 21)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', rot=85, legend=False)

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', rot=85, legend=False)
